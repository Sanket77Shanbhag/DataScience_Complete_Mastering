# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Series**: Holds data of any type

# %%
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
data = {'a':0.,'b':1.,'c':2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
s = pd.Series(5,index=range(0,4))
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %% [markdown]
# **Data Frame**

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print(df)
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0
# <ipython-input-13-6b31be86e27c>:2: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)

# %%
data = {'Name':['Tom','Jack','Steve','Ricky'],'Age':[25,34,26,47]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Tom   25
# 1   Jack   34
# 2  Steve   26
# 3  Ricky   47

# %% [markdown]
# **Operations**

# %% [markdown]
# **1. Column selection**

# %%
d = {'one': pd.Series ([1, 2, 3], index=['a', 'b', 'c']), 'two' : pd.Series ([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df ['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %% [markdown]
# **2. Column Addition**

# %%
d = {'one' : pd.Series ([1, 2, 3], index=['a', 'b', 'c']), 'two' : pd.Series ([1, 2, 3, 4], index=['a','b','c','d'])}
df = pd.DataFrame(d)
print ("Adding a new column by passing as Series:")
df['three']=pd.Series ([10,20,30], index=['a', 'b', 'c'])
print(df)
print ("Adding a new column using the existing columns in DataFrame:")
df['four'] =df ['one']+df['three']
print(df)
# Out:
# Adding a new column by passing as Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Adding a new column using the existing columns in DataFrame:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %% [markdown]
# **3. Column Deletion**

# %%
d = {'one' : pd.Series ([1, 2, 3], index=['a', 'b', 'c']), 'two' : pd.Series ([1, 2, 3, 4], index=['a','b','c','d']),'three': pd.Series ([10, 20, 30], index=['a', 'b', 'c'])}
df = pd.DataFrame(d)
print ("Our dataframe is:")
print(df)
print ("Deleting the first column using DEL function:")
del df['one']
print(df)
print ("Deleting another column using POP function:")
df.pop('two')
print(df)
# Out:
# Our dataframe is:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Deleting the first column using DEL function:
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
# Deleting another column using POP function:
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %% [markdown]
# **4. Row Selection**

# %% [markdown]
# **a. Selection by label**

# %%
d = {'one': pd.Series([1,2,3],index=['a','b','c']),'two': pd.Series([1,2,3,4],index=['a','b','c','d'])}
df = pd.DataFrame(d)
print(df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %% [markdown]
# **b. Selection by integer location**

# %%
d = {'one': pd.Series([1,2,3],index=['a','b','c']),'two': pd.Series([1,2,3,4],index=['a','b','c','d'])}
df = pd.DataFrame(d)
print(df.iloc[2])
# Out:
# one    3.0
# two    3.0
# Name: c, dtype: float64

# %% [markdown]
# **5. Row Slicing**

# %%
d = {'one': pd.Series([1,2,3],index=['a','b','c']),'two': pd.Series([1,2,3,4],index=['a','b','c','d'])}
df = pd.DataFrame(d)
print(df)
print(df[2:3])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two
# c  3.0    3

# %% [markdown]
# **6. Addition of Rows**

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a', 'b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a', 'b'])
df = df.append(df2)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
# <ipython-input-6-1b6ff9d75a27>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %% [markdown]
# **7. Deletion of rows**

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a', 'b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a', 'b'])
df = df.append(df2)
print(df)
df = df.drop(0)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
#    a  b
# 1  3  4
# 1  7  8
# <ipython-input-7-0988ab7a09fb>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %% [markdown]
# **Practice questions**

# %%
my_list = ['geeks', 'for', 'geeks']
another_list = [6, 0, 4, 1]
my_list.append(another_list)
print (my_list)
# Out:
# ['geeks', 'for', 'geeks', [6, 0, 4, 1]]

# %%
import pandas as pd
player_list = [['M.S.Dhoni', 36, 75, 5428000],
            ['A.B.D Villers', 38, 74, 3428000],
            ['V.Kohli', 31, 70, 8428000],
            ['S.Smith', 34, 80, 4428000],
            ['C.Gayle', 40, 100, 4528000],
            ['J.Root', 33, 72, 7028000],
            ['K.Peterson', 42, 85, 2528000]]
df = pd.DataFrame(player_list, columns=['Name', 'Age', 'Weight', 'Salary'])
df
# Out:
#             Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 2        V.Kohli   31      70  8428000
# 3        S.Smith   34      80  4428000
# 4        C.Gayle   40     100  4528000
# 5         J.Root   33      72  7028000
# 6     K.Peterson   42      85  2528000

# %%
df1 = df.iloc[:, 0:2]
df1
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %%
import pandas as pd
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 37],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
df = pd.DataFrame(data)
df.loc[1:3, ['Name', 'Qualification']]
# Out:
#      Name Qualification
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
import pandas as pd
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
df = pd.DataFrame(data)
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
df['Address'] = address
print(df)
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           Msc      Delhi
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           Msc    Chennai
# 3    Anuj     5.2           Msc      Patna

# %%
import pandas as pd
df = pd.DataFrame({'X':[1, 2, 3, 4, 5],
                'Y':[54, 12, 57, 48, 96]})
df = df.sum(axis = 1)
print(df)
# Out:
# 0     55
# 1     14
# 2     60
# 3     52
# 4    101
# dtype: int64

# %% [markdown]
# **Data Visualization in Pandas**

# %% [markdown]
# **1. Simple Line Plot**

# %%
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('11/6/2023',periods=10),columns=list('ABCD'))
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# **2. Bar Plot**

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Stacked bar graph

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# Horizontal bar graph - barh() function

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# **3. Box Plot**

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# **4. Scatter Plot**

# %%
df = pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# **5. Pie Chart**

# %%
df = pd.DataFrame(3*np.random.rand(4),index=['a','b','c','d'],columns=['x'])
df.plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='x'>], dtype=object)
